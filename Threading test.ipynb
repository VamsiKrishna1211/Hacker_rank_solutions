# %%
import threading
# count1=0
# count2=0
# count3=0
# count4=0
  
def first(): 
    """ 
    function to print cube of given num 
    """
    count1=0
    a=111111111111111111111111111111111111111111111111111111111111111111111
    b=221233333333333333331222222222222222322222222242222222222466666666
    while(1):
        if(count1%(1000)==0):
            print("First thread executed: ",count1)
        a=a*b
        count1+=1

    
def second(): 
    """ 
    function to print square of given num 
    """
    count2=0
    a=111111111111111111111111111111111111111111111111111111111111111111111
    b=221233333333333333331222222222222222322222222242222222222466666666
    while(1):
        if(count2%(1000)==0):
            print("second thread executed: ",count2)
        a=a*b
        count2+=1
        
def third(): 
    """ 
    function to print cube of given num 
    """
    count3=0
    a=111111111111111111111111111111111111111111111111111111111111111111111
    b=221233333333333333331222222222222222322222222242222222222466666666
    while(1):
        if(count3%(1000)==0):
            print("third thread executed: ",count3)
        a=a*b
        count3+=1
        
def forth(): 
    """ 
    function to print cube of given num 
    """
    count4=0
    a=111111111111111111111111111111111111111111111111111111111111111111111
    b=221233333333333333331222222222222222322222222242222222222466666666
    while(1):
        if(count4%(1000)==0):
            print("Fourth thread executed: ",count4)
        a=a*b
        count4+=1

    
if __name__ == "__main__": 
    # creating thread 
    t1 = threading.Thread(target=first) 
    t2 = threading.Thread(target=second)
    t3 = threading.Thread(target=third)
    t4 = threading.Thread(target=forth)
    # starting thread 1 
    t1.start() 
    # starting thread 2 
    t2.start()
    t3.start()
    t4.start()
  
    # wait until thread 1 is completely executed 
    t1.join() 
    # wait until thread 2 is completely executed 
    t2.join()
    t3.join()
    t4.join()
  
    # both threads completely executed 
    print("Done!")
# Out:
# First thread executed:  0
# second thread executed:  0
# third thread executed:  111111111111111111111111111111111111111111111111111111111111111111111
# First thread executed:  1000
# second thread executed: second thread executed:  1000
#  14000
# third thread executed:  ...
# third thread executed:  14000
# First thread executed:  2000
# Fourth thread executed:  14000
# second thread executed:  2000third thread executed:
# ...
# First thread executed:  14000
# First thread executed:  3000
# second thread executed:  3000
# third thread executed:  ...
# second thread executed: First thread executed:  4000
#  4000
# third thread executed:  ...
# First thread executed:  5000
# second thread executed:  5000
# third thread executed:  ...
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Fourth thread executed:  15000
# third thread executed: second thread executed:  15000
#  15000
# Traceback (most recent call last):
# ...
