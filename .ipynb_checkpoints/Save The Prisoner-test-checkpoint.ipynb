# %%
def saveThePrisoner(n,m,s):
    war=s
    for i in range(m):
        war+=1
        if(war>n):
            war=1
    if (war==1):
        return n
    else:
        return war-1


if __name__=="__main__":
#     f=open("/home/vamsik1211/git_repos/Hacker_rank_solutions/save_the_prisoner_testCases.txt")
#     f.seek(0)
#     no_itr=int(f.readline())
#     for i in range(no_itr):
#         prisoners,sweets,start_chair=map(int, f.readline().rstrip().split())
#         warning_chair= saveThePrisoner(prisoners,sweets,start_chair)
#         print(warning_chair)
        
#     f=open("/home/vamsik1211/git_repos/Hacker_rank_solutions/save_the_prisoner_testCases.txt")
#     sol=open("/home/vamsik1211/git_repos/Hacker_rank_solutions/save_the_prisoner_solutions.txt")
#     f.seek(0)
#     sol.seek(0)
    #no_itr=int(f.readline())
    no_itr=int(input())
    for i in range(no_itr):
        prisoners,sweets,start_chair=map(int, input().rstrip().split())
        warning_chair= saveThePrisoner(prisoners,sweets,start_chair)
        print(warning_chair)
#         ans=int(sol.readline())
#         print(warning_chair,"\t",ans,end="")
#         if(warning_chair==ans):
#             print("\tYES!!\t",start_chair,"\t",prisoners,"\t",sweets)
#             continue
#         else:
#             print("\tNO :(\t",start_chair,"\t",prisoners,"\t",sweets)
# Out:
# 1
# 5 2 2
# 3

# %%
def saveThePrisoner(n,m,s):
    n_clone=n
    m_clone=m
    if (m_clone>=n_clone):
        n_clone=m_clone-n_clone
        if (s+n_clone-1>n):
            return 0
        else:
            return s+n_clone-1
    
    else:
        return 0
    
        


if __name__=="__main__":
    f=open("/home/vamsik1211/git_repos/Hacker_rank_solutions/save_the_prisoner_testCases.txt")
    sol=open("/home/vamsik1211/git_repos/Hacker_rank_solutions/save_the_prisoner_solutions.txt")
    f.seek(0)
    sol.seek(0)
    no_itr=int(f.readline())
    for i in range(no_itr):
        prisoners,sweets,start_chair=map(int, f.readline().rstrip().split())
        warning_chair= saveThePrisoner(prisoners,sweets,start_chair)
        ans=int(sol.readline())
        print(warning_chair,"\t",end="")#,ans,end="")
        if(warning_chair==ans):
            print("YES!!\t")#,start_chair,"\t",prisoners,"\t",sweets)
            continue
        else:
            print("NO :(\t")#,start_chair,"\t",prisoners,"\t",sweets)
# Out:
# 122129406 	YES!!
# 0 	NO :(
# 0 	NO :(
# 405956028 	YES!!
# 0 	NO :(
# 0 	NO :(
# 0 	NO :(
# 0 	NO :(
# 0 	NO :(
# 0 	NO :(
# 269539705 	YES!!
# 0 	NO :(
# 115810626 	YES!!
# 0 	NO :(
# 216062299 	YES!!
# 0 	NO :(
# 0 	NO :(
# 674567416 	YES!!
# 0 	NO :(
# 200235842 	YES!!
# 350805362 	YES!!
# 0 	NO :(
# 0 	NO :(
# 0 	NO :(
# 8773474 	YES!!
# 425809870 	YES!!
# 544652109 	YES!!
# 0 	NO :(
# 519193865 	YES!!
# 422682546 	YES!!
# 0 	NO :(
# 262019564 	YES!!
# 821934714 	YES!!
# 588497214 	YES!!
# 460522527 	YES!!
# 385897437 	YES!!
# 333906011 	YES!!
# 0 	NO :(
# 478754860 	YES!!
# 0 	NO :(
# 0 	NO :(
# 0 	NO :(
# 739548684 	YES!!
# 0 	NO :(
# 537798717 	YES!!
# 332932745 	YES!!
# 0 	NO :(
# 755555371 	YES!!
# 239799957 	YES!!
# 0 	NO :(
# 87501244 	YES!!
# 0 	NO :(
# 388484637 	YES!!
# 0 	NO :(
# 0 	NO :(
# 387228584 	YES!!
# 0 	NO :(
# 0 	NO :(
# 465233083 	YES!!
# 592129096 	YES!!
# 171623012 	YES!!
# 0 	NO :(
# 0 	NO :(
# 0 	NO :(
# 0 	NO :(
# 0 	NO :(
# 0 	NO :(
# 0 	NO :(
# ...

# %%
# Out:
#   File "<ipython-input-26-0b024bbfe84e>", line 1
#     +
#      ^
# SyntaxError: invalid syntax

# %%
def saveThePrisoner(n,m,s):
    n_clone=n
    m_clone=m
    div = m_clone/n_clone
    div = int(div)
    if (m_clone>n_clone):
        n_clone=m_clone-(n_clone*((div)))
        if (s+n_clone-1>n):
            return s+n_clone-1-n
            
            
            #return (s+n_clone-1)
        else:
            
            return s+n_clone-1
    
    elif(m_clone==n_clone):
        return n_clone
    else:
        return 0
    
        


if __name__=="__main__":
    f=open("/home/vamsik1211/git_repos/Hacker_rank_solutions/save_the_prisoner_testCases.txt")
    sol=open("/home/vamsik1211/git_repos/Hacker_rank_solutions/save_the_prisoner_solutions.txt")
    f.seek(0)
    sol.seek(0)
    no_itr=int(f.readline())
    for i in range(no_itr):
        prisoners,sweets,start_chair=map(int, f.readline().rstrip().split())
        warning_chair= saveThePrisoner(prisoners,sweets,start_chair)
        ans=int(sol.readline())
        print(warning_chair,"\t",ans,end="")
        if(warning_chair==ans):
            print("\tYES!!\t",start_chair,"\t",prisoners,"\t",sweets)
            continue
        else:
            print("\tNO :(\t",start_chair,"\t",prisoners,"\t",sweets)
# Out:
# 122129406 	 122129406	YES!!	 94730870 	 352926151 	 380324688
# 23525398 	 23525398	YES!!	 5284458 	 94431605 	 679262176
# 72975907 	 72975907	YES!!	 150817879 	 208526924 	 756265725
# 405956028 	 405956028	YES!!	 396355184 	 962975336 	 972576181
# 265162707 	 265162707	YES!!	 255816794 	 464237185 	 937820284
# 91803604 	 91803604	YES!!	 647542323 	 649320641 	 742902564
# 82636723 	 82636723	YES!!	 68977959 	 174512033 	 711706897
# 9258153 	 9258153	YES!!	 67149447 	 107283902 	 156676511
# 81152217 	 81152217	YES!!	 96292548 	 104513201 	 298399273
# 31978708 	 31978708	YES!!	 98103763 	 113378824 	 274011418
# 269539705 	 269539705	YES!!	 212396037 	 934815799 	 991959468
# 18445097 	 18445097	YES!!	 24617705 	 88325121 	 435452998
# 115810626 	 115810626	YES!!	 103050157 	 984873585 	 997634055
# 117586280 	 117586280	YES!!	 90658180 	 344218387 	 715364875
# 216062299 	 216062299	YES!!	 156417592 	 556065259 	 615709967
# ...

# %%
def saveThePrisoner(n,m,s):
    n_clone=n
    m_clone=m
    div = m_clone/n_clone
    div = int(div)
    if (m_clone>n_clone):
        n_clone=m_clone-(n_clone*((div)))
        if (s+n_clone-1>n):
            return s+n_clone-1-n
            
            
            #return (s+n_clone-1)
        else:
            
            return s+n_clone-1
    
    elif(m_clone==n_clone):
        return n_clone
    else:
        if (s+m<=n):
            return m+s-1
        else:
            return s+m-n-1
        
    
        


if __name__=="__main__":
#     f=open("/home/vamsik1211/git_repos/Hacker_rank_solutions/save_the_prisoner_testCases.txt")
#     sol=open("/home/vamsik1211/git_repos/Hacker_rank_solutions/save_the_prisoner_solutions.txt")
#     f.seek(0)
#     sol.seek(0)
    #no_itr=int(f.readline())
    no_itr=int(input())
    for i in range(no_itr):
        prisoners,sweets,start_chair=map(int, input().rstrip().split())
        warning_chair= saveThePrisoner(prisoners,sweets,start_chair)
        print(warning_chair)
#         ans=int(sol.readline())
#         print(warning_chair,"\t",ans,end="")
#         if(warning_chair==ans):
#             print("\tYES!!\t",start_chair,"\t",prisoners,"\t",sweets)
#             continue
#         else:
#             print("\tNO :(\t",start_chair,"\t",prisoners,"\t",sweets)
